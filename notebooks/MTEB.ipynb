# %%
import pandas as pd

# %%
mteb = pd.read_csv("../data/mteb.csv")
mteb.head()
# Out:
#    Unnamed: 0  Rank (Borda)  \
# 0           0             1
# 1           1             2
# 2           2             3
# 3           3             4
# 4           4             5
#
#                                                Model Zero-shot  \
# 0  [harrier-oss-v1-27b](https://huggingface.co/mi...       78%
# 1  [KaLM-Embedding-Gemma3-12B-2511](https://huggi...       73%
# 2  [llama-embed-nemotron-8b](https://huggingface....       99%
# 3  [Qwen3-Embedding-8B](https://huggingface.co/Qw...       99%
# 4  [gemini-embedding-001](https://ai.google.dev/g...       99%
#
#    Active Parameters (B)  Total Parameters (B)  Embedding Dimensions  \
# 0                 25.599                27.009                5376.0
# 1                 10.759                11.766                3840.0
# 2                  6.980                 7.505                4096.0
# 3                  6.946                 7.567                4096.0
# ...

# %%
mteb.sort_values("Clustering", ascending=False).head(20)[["Model", "Clustering"]]
# Out:
#                                                 Model  Clustering
# 7   [F2LLM-v2-14B](https://huggingface.co/codefuse...       60.91
# 8   [F2LLM-v2-8B](https://huggingface.co/codefuse-...       60.62
# 11  [F2LLM-v2-4B](https://huggingface.co/codefuse-...       59.53
# 0   [harrier-oss-v1-27b](https://huggingface.co/mi...       58.93
# 13  [F2LLM-v2-1.7B](https://huggingface.co/codefus...       58.77
# 3   [Qwen3-Embedding-8B](https://huggingface.co/Qw...       57.65
# 5   [Qwen3-Embedding-4B](https://huggingface.co/Qw...       57.15
# 10  [Seed1.6-embedding-1215](https://console.volce...       56.78
# 21  [F2LLM-v2-0.6B](https://huggingface.co/codefus...       56.58
# 1   [KaLM-Embedding-Gemma3-12B-2511](https://huggi...       55.77
# 6   [Octen-Embedding-8B](https://huggingface.co/Oc...       55.68
# 35  [F2LLM-v2-330M](https://huggingface.co/codefus...       54.69
# 4   [gemini-embedding-001](https://ai.google.dev/g...       54.59
# ...
